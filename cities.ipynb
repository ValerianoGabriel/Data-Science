# %%
import pandas as pd
import re

# %%
sweethome = pd.read_csv('aus_real_estate.csv')
sweethome
# Out:
#         Price  Bedrooms  Bathrooms  SqFt       City State  Year_Built  \
# 0      982112         4          1  1561   Adelaide   QLD        2021
# 1      571388         3          2  3735  Melbourne   VIC        1999
# 2      866821         5          1  2032     Sydney   VIC        1976
# 3     1230977         4          3  3861   Brisbane    SA        1978
# 4      241787         4          2  3150      Perth    SA        1992
# ...       ...       ...        ...   ...        ...   ...         ...
# 4995   682555         4          3   887   Adelaide   QLD        2012
# 4996  1634457         3          1  1117   Brisbane   QLD        2020
# 4997  1209978         4          1   992      Perth   QLD        2008
# 4998  1976680         3          3  1825     Sydney   QLD        1957
# 4999  1470344         2          2  2103   Brisbane    SA        1965
#
#            Type  Garage  Lot_Area
# 0     Townhouse       0      1357
# 1         House       1      8397
# ...

# %%
sweethome.loc[(sweethome['City'] == 'Perth') & (sweethome['Year_Built'] > 2015) & (sweethome['Type'] == 'House') & (sweethome['Price'] < 300000)]
# Out:
#        Price  Bedrooms  Bathrooms  SqFt   City State  Year_Built   Type  \
# 617   221756         5          3  3587  Perth    WA        2021  House
# 1257  268162         1          2  3653  Perth   QLD        2016  House
# 2340  213392         1          3  2572  Perth    SA        2020  House
#
#       Garage  Lot_Area
# 617        0      2872
# 1257       1      4680
# 2340       0      3813

# %%
sweethome.loc[(sweethome['City'] == 'Perth') & (sweethome['State'] != 'WA')]
# Out:
#         Price  Bedrooms  Bathrooms  SqFt   City State  Year_Built       Type  \
# 4      241787         4          2  3150  Perth    SA        1992  Apartment
# 24     983015         5          1  2602  Perth   NSW        1989      House
# 29     402195         5          1  2566  Perth   NSW        1970      House
# 30    1617926         1          2  1389  Perth   VIC        2012  Townhouse
# 39     877191         2          2  3953  Perth   QLD        1999      House
# ...       ...       ...        ...   ...    ...   ...         ...        ...
# 4979  1200106         4          3  3827  Perth   QLD        1962      House
# 4980   342972         4          2  3578  Perth   VIC        1975      House
# 4983  1345517         4          3  2498  Perth   NSW        1951  Apartment
# 4988  1992719         1          1  2971  Perth   NSW        2011  Apartment
# 4997  1209978         4          1   992  Perth   QLD        2008      House
#
#       Garage  Lot_Area
# ...

# %%
realone = sweethome.loc[(sweethome['City'] == 'Perth') & (sweethome['State'] == 'WA')]
realone
# Out:
#         Price  Bedrooms  Bathrooms  SqFt   City State  Year_Built       Type  \
# 28     671877         2          1  2189  Perth    WA        2016  Townhouse
# 60    1780590         5          2  1291  Perth    WA        1963  Townhouse
# 206    590975         2          1  2723  Perth    WA        2009  Apartment
# 247    766581         2          1  1510  Perth    WA        2016  Apartment
# 287   1381044         2          3  2613  Perth    WA        2010  Apartment
# ...       ...       ...        ...   ...    ...   ...         ...        ...
# 4849  1474483         4          2  2344  Perth    WA        1997  Townhouse
# 4859  1004725         3          3  2036  Perth    WA        1991      House
# 4872   559501         5          2  2863  Perth    WA        1996  Apartment
# 4930  1330429         3          1  2905  Perth    WA        2015  Apartment
# 4935   709722         4          1  3242  Perth    WA        2002  Townhouse
#
#       Garage  Lot_Area
# ...

# %%
sweethome.loc[sweethome['City'] == 'Perth', 'State'] = sweethome['State'].replace(['QLD', 'NSW', 'VIC', 'SA'], 'WA')

# %%
sweethome.loc[sweethome['City'] == 'Sydney', 'State'] = sweethome['State'].replace(['WA', 'QLD', 'VIC', 'SA'], 'NSW')

# %%
sweethome.loc[sweethome['City'] == 'Adelaide', 'State'] = sweethome['State'].replace(['WA','QLD', 'VIC', 'NSW'], 'SA')

# %%
sweethome.loc[sweethome['City'] == 'Brisbane', 'State'] = sweethome['State'].replace(['WA','NSW','VIC','SA'], 'QLD')

# %%
sweethome
# Out:
#         Price  Bedrooms  Bathrooms  SqFt       City State  Year_Built  \
# 0      982112         4          1  1561   Adelaide    SA        2021
# 1      571388         3          2  3735  Melbourne   VIC        1999
# 2      866821         5          1  2032     Sydney   NSW        1976
# 3     1230977         4          3  3861   Brisbane   QLD        1978
# 4      241787         4          2  3150      Perth    WA        1992
# ...       ...       ...        ...   ...        ...   ...         ...
# 4995   682555         4          3   887   Adelaide    SA        2012
# 4996  1634457         3          1  1117   Brisbane   QLD        2020
# 4997  1209978         4          1   992      Perth    WA        2008
# 4998  1976680         3          3  1825     Sydney   NSW        1957
# 4999  1470344         2          2  2103   Brisbane   QLD        1965
#
#            Type  Garage  Lot_Area
# 0     Townhouse       0      1357
# 1         House       1      8397
# ...
